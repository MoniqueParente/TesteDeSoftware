# %%
import psycopg2
import random 
import string 
import time 

# Configuracao de conexao ao banco de dados para
host ='localhost'
port = '1372'
database = 'postgres'
user = 'postgres'
password = '1234567'

def execute_query(query):
    conn = psycopg2.connect(host=host, port=port, 
                            database=database, user=user ,password=password)
    cursor = conn.cursor()
    cursor.execute(query)
    result = cursor.fetchall()
    cursor.close()
    conn.close()

def perform_load_test(num_queries):
    start_time = time.time()
    for i in range(num_queries):
        query = "SELECT count(*) FROM tabela_exemplo;"
        result = execute_query(query)
        print(f"consulta{i+1} : {result}")

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"\n Tempo Total de execucao : {elapsed_time} segundos")
    print(f"\n Tempo medio por consulta: {elapsed_time / num_queries} segundos")

perform_load_test(10000)
# Out:
# consulta1 : None
# consulta2 : None
# consulta3 : None
# consulta4 : None
# consulta5 : None
# consulta6 : None
# consulta7 : None
# consulta8 : None
# consulta9 : None
# consulta10 : None
# consulta11 : None
# consulta12 : None
# consulta13 : None
# consulta14 : None
# consulta15 : None
# consulta16 : None
# consulta17 : None
# consulta18 : None
# consulta19 : None
# consulta20 : None
# consulta21 : None
# consulta22 : None
# consulta23 : None
# consulta24 : None
# consulta25 : None
# consulta26 : None
# consulta27 : None
# consulta28 : None
# consulta29 : None
# consulta30 : None
# consulta31 : None
# consulta32 : None
# consulta33 : None
# consulta34 : None
# consulta35 : None
# consulta36 : None
# consulta37 : None
# consulta38 : None
# consulta39 : None
# consulta40 : None
# consulta41 : None
# consulta42 : None
# consulta43 : None
# consulta44 : None
# consulta45 : None
# consulta46 : None
# consulta47 : None
# consulta48 : None
# consulta49 : None
# consulta50 : None
# consulta51 : None
# consulta52 : None
# consulta53 : None
# consulta54 : None
# consulta55 : None
# consulta56 : None
# consulta57 : None
# consulta58 : None
# consulta59 : None
# consulta60 : None
# consulta61 : None
# consulta62 : None
# consulta63 : None
# consulta64 : None
# consulta65 : None
# consulta66 : None
# consulta67 : None
# consulta68 : None
# consulta69 : None
# consulta70 : None
# consulta71 : None
# consulta72 : None
# consulta73 : None
# consulta74 : None
# consulta75 : None
# consulta76 : None
# consulta77 : None
# consulta78 : None
# consulta79 : None
# consulta80 : None
# consulta81 : None
# consulta82 : None
# consulta83 : None
# consulta84 : None
# consulta85 : None
# consulta86 : None
# consulta87 : None
# consulta88 : None
# consulta89 : None
# consulta90 : None
# consulta91 : None
# consulta92 : None
# consulta93 : None
# consulta94 : None
# consulta95 : None
# consulta96 : None
# consulta97 : None
# consulta98 : None
# consulta99 : None
# consulta100 : None
# consulta101 : None
# consulta102 : None
# consulta103 : None
# consulta104 : None
# consulta105 : None
# consulta106 : None
# consulta107 : None
# consulta108 : None
# consulta109 : None
# consulta110 : None
# consulta111 : None
# consulta112 : None
# consulta113 : None
# consulta114 : None
# consulta115 : None
# consulta116 : None
# consulta117 : None
# consulta118 : None
# consulta119 : None
# consulta120 : None
# consulta121 : None
# consulta122 : None
# consulta123 : None
# consulta124 : None
# consulta125 : None
# consulta126 : None
# consulta127 : None
# consulta128 : None
# consulta129 : None
# consulta130 : None
# consulta131 : None
# consulta132 : None
# consulta133 : None
# consulta134 : None
# consulta135 : None
# consulta136 : None
# consulta137 : None
# consulta138 : None
# consulta139 : None
# consulta140 : None
# consulta141 : None
# consulta142 : None
# consulta143 : None
# consulta144 : None
# consulta145 : None
# consulta146 : None
# consulta147 : None
# consulta148 : None
# consulta149 : None
# consulta150 : None
# consulta151 : None
# consulta152 : None
# consulta153 : None
# consulta154 : None
# consulta155 : None
# consulta156 : None
# consulta157 : None
# consulta158 : None
# consulta159 : None
# consulta160 : None
# consulta161 : None
# consulta162 : None
# consulta163 : None
# consulta164 : None
# consulta165 : None
# consulta166 : None
# consulta167 : None
# consulta168 : None
# consulta169 : None
# consulta170 : None
# consulta171 : None
# consulta172 : None
# consulta173 : None
# consulta174 : None
# consulta175 : None
# consulta176 : None
# consulta177 : None
# consulta178 : None
# consulta179 : None
# consulta180 : None
# consulta181 : None
# consulta182 : None
# consulta183 : None
# consulta184 : None
# consulta185 : None
# consulta186 : None
# consulta187 : None
# consulta188 : None
# consulta189 : None
# consulta190 : None
# consulta191 : None
# consulta192 : None
# consulta193 : None
# consulta194 : None
# consulta195 : None
# consulta196 : None
# consulta197 : None
# consulta198 : None
# consulta199 : None
# consulta200 : None
# consulta201 : None
# consulta202 : None
# consulta203 : None
# consulta204 : None
# consulta205 : None
# consulta206 : None
# consulta207 : None
# consulta208 : None
# consulta209 : None
# consulta210 : None
# consulta211 : None
# consulta212 : None
# consulta213 : None
# consulta214 : None
# consulta215 : None
# consulta216 : None
# consulta217 : None
# consulta218 : None
# consulta219 : None
# consulta220 : None
# consulta221 : None
# consulta222 : None
# consulta223 : None
# consulta224 : None
# consulta225 : None
# consulta226 : None
# consulta227 : None
# consulta228 : None
# consulta229 : None
# consulta230 : None
# consulta231 : None
# consulta232 : None
# consulta233 : None
# consulta234 : None
# consulta235 : None
# consulta236 : None
# consulta237 : None
# consulta238 : None
# consulta239 : None
# consulta240 : None
# consulta241 : None
# consulta242 : None
# consulta243 : None
# consulta244 : None
# consulta245 : None
# consulta246 : None
# consulta247 : None
# consulta248 : None
# consulta249 : None
# consulta250 : None
# consulta251 : None
# consulta252 : None
# consulta253 : None
# consulta254 : None
# consulta255 : None
# consulta256 : None
# consulta257 : None
# consulta258 : None
# consulta259 : None
# consulta260 : None
# consulta261 : None
# consulta262 : None
# consulta263 : None
# consulta264 : None
# consulta265 : None
# consulta266 : None
# consulta267 : None
# consulta268 : None
# consulta269 : None
# consulta270 : None
# consulta271 : None
# consulta272 : None
# consulta273 : None
# consulta274 : None
# consulta275 : None
# consulta276 : None
# consulta277 : None
# consulta278 : None
# consulta279 : None
# consulta280 : None
# consulta281 : None
# consulta282 : None
# consulta283 : None
# consulta284 : None
# consulta285 : None
# consulta286 : None
# consulta287 : None
# consulta288 : None
# consulta289 : None
# consulta290 : None
# consulta291 : None
# consulta292 : None
# consulta293 : None
# consulta294 : None
# consulta295 : None
# consulta296 : None
# consulta297 : None
# consulta298 : None
# consulta299 : None
# consulta300 : None
# consulta301 : None
# consulta302 : None
# consulta303 : None
# consulta304 : None
# consulta305 : None
# consulta306 : None
# consulta307 : None
# consulta308 : None
# consulta309 : None
# consulta310 : None
# consulta311 : None
# consulta312 : None
# consulta313 : None
# consulta314 : None
# consulta315 : None
# consulta316 : None
# consulta317 : None
# consulta318 : None
# consulta319 : None
# consulta320 : None
# consulta321 : None
# consulta322 : None
# consulta323 : None
# consulta324 : None
# consulta325 : None
# consulta326 : None
# consulta327 : None
# consulta328 : None
# consulta329 : None
# consulta330 : None
# consulta331 : None
# consulta332 : None
# consulta333 : None
# consulta334 : None
# consulta335 : None
# consulta336 : None
# consulta337 : None
# consulta338 : None
# consulta339 : None
# consulta340 : None
# consulta341 : None
# consulta342 : None
# consulta343 : None
# consulta344 : None
# consulta345 : None
# consulta346 : None
# consulta347 : None
# consulta348 : None
# consulta349 : None
# consulta350 : None
# consulta351 : None
# consulta352 : None
# consulta353 : None
# consulta354 : None
# consulta355 : None
# consulta356 : None
# consulta357 : None
# consulta358 : None
# consulta359 : None
# consulta360 : None
# consulta361 : None
# consulta362 : None
# consulta363 : None
# consulta364 : None
# consulta365 : None
# consulta366 : None
# consulta367 : None
# consulta368 : None
# consulta369 : None
# consulta370 : None
# consulta371 : None
# consulta372 : None
# consulta373 : None
# consulta374 : None
# consulta375 : None
# consulta376 : None
# consulta377 : None
# consulta378 : None
# consulta379 : None
# consulta380 : None
# consulta381 : None
# consulta382 : None
# consulta383 : None
# consulta384 : None
# consulta385 : None
# consulta386 : None
# consulta387 : None
# consulta388 : None
# consulta389 : None
# consulta390 : None
# consulta391 : None
# consulta392 : None
# consulta393 : None
# consulta394 : None
# consulta395 : None
# consulta396 : None
# consulta397 : None
# consulta398 : None
# consulta399 : None
# consulta400 : None
# consulta401 : None
# consulta402 : None
# consulta403 : None
# consulta404 : None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 34
#      31     print(f"\n Tempo Total de execucao : {elapsed_time} segundos")
#      32     print(f"\n Tempo medio por consulta: {elapsed_time / num_queries} segundos")
# ---> 34 perform_load_test(10000)
#
# Cell In[9], line 26, in perform_load_test(num_queries)
#      24 for i in range(num_queries):
#      25     query = "SELECT count(*) FROM tabela_exemplo;"
# ---> 26     result = execute_query(query)
#      27     print(f"consulta{i+1} : {result}")
#      29 end_time = time.time()
#
# Cell In[9], line 14, in execute_query(query)
#      13 def execute_query(query):
# ---> 14     conn = psycopg2.connect(host=host, port=port,
#      15                             database=database, user=user ,password=password)
#      16     cursor = conn.cursor()
#      17     cursor.execute(query)
#
# File c:\Users\moniq\AppData\Local\Programs\Python\Python310\lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# KeyboardInterrupt:
